# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #1. Data Analysis:
# - isna(), info(), decribe(), crosstab()
# - plots
# - correlation matrix
# - sort data by date

# %%
file_path = "/content/drive/MyDrive/House Price Prediction/Bengaluru_House_Data.csv"
data = pd.read_csv(file_path)
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %% [markdown]
# #2. Clean Data:
# - Dropping rows and columns based on null values

# %%
df = data.copy()
data.isna().sum()
# for price : 0, therefore no need to remove rows
# lets drop : society, since almost half of the dataset has null value
# lets drop the row which has null value for location and size
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
# prompt: drop the row which has null value for location
df = df.dropna(axis=0, subset=['location','size'])
df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           0
# size               0
# society         5499
# total_sqft         0
# bath              57
# balcony          593
# price              0
# dtype: int64

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
# prompt: drop society column
df.drop(columns=['society','area_type','balcony'], axis=1, inplace=True)
df.isna().sum()
# Out:
# availability     0
# location         0
# size             0
# total_sqft       0
# bath            57
# price            0
# dtype: int64

# %% [markdown]
# #3. Handling Features:
# - Check isna().sum() for each feature, if not significant proceed
# - Make the feature ready for one hot encoding
# - Remove unique values which has less number of counts
# - Modify and clean the values in each feature column accordingly

# %% [markdown]
# ##Availability

# %%
df['availability'].isna().sum()
#proceed in this section
# Out:
# 0

# %%
df['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        '19-May', '17-Nov', '20-Oct', '20-Jun', '19-Feb', '21-Oct',
#        '21-Jan', '17-Mar', '17-Apr', '22-May', '19-Oct', '21-Jul',
#        '21-Nov', '21-Mar', '16-Dec', '22-Mar', '20-Jan', '21-Sep',
#        '21-Aug', '14-Nov', '19-Nov', '15-Nov', '16-Jul', '15-Jun',
#        '17-Feb', '20-Nov', '20-Jul', '16-Sep', '15-Oct', '15-Dec',
#        '16-Oct', '22-Nov', '15-Aug', '17-Jan', '16-Nov', '20-Apr',
#        '16-Jan', '14-Jul'], dtype=object)

# %%
# Update the availability column
df['availability'] = df['availability'].apply(lambda x: 'Future Possession' if x != 'Ready To Move' else x)
df['availability'] = df['availability'].apply(lambda x: 'Future Possession' if x != 'Ready To Move' else x)

# %%
df['availability'].unique()
# Out:
# array(['Future Possession', 'Ready To Move'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13303 entries, 0 to 13319
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   availability  13303 non-null  object
#  1   location      13303 non-null  object
#  2   size          13303 non-null  object
#  3   total_sqft    13303 non-null  object
#  4   bath          13246 non-null  float64
#  5   price         13303 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 727.5+ KB

# %% [markdown]
# ##Location

# %%
df['location'].isna().sum()
#proceed in this section
# Out:
# 0

# %%
len(df['location'].unique())
# Out:
# 1304

# %%
df['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
df.head()
# Out:
#         availability                  location       size total_sqft  bath  \
# 0  Future Possession  Electronic City Phase II      2 BHK       1056   2.0
# 1      Ready To Move          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2      Ready To Move               Uttarahalli      3 BHK       1440   2.0
# 3      Ready To Move        Lingadheeranahalli      3 BHK       1521   3.0
# 4      Ready To Move                  Kothanur      2 BHK       1200   2.0
#
#     price
# 0   39.07
# 1  120.00
# 2   62.00
# 3   95.00
# 4   51.00

# %%
# Calculate the frequency of each location
location_counts = df['location'].value_counts()

# Identify locations that appear less than 20 times
locations_to_replace = location_counts[location_counts < 20].index

# Replace these locations with 'others' in the DataFrame
df['location'] = df['location'].apply(lambda x: 'others' if x in locations_to_replace else x)

# Verify the change by checking the unique values and their counts again
print(df['location'].value_counts())
# Out:
# others                  4216
# Whitefield               539
# Sarjapur  Road           397
# Electronic City          302
# Kanakpura Road           273
#                         ...
# Hoskote                   21
# Yelachenahalli            20
# HBR Layout                20
# Sanjay nagar              20
# Poorna Pragna Layout      20
# Name: location, Length: 149, dtype: int64

# %% [markdown]
# ##Size

# %%
df['size'].isna().sum()
#proceed in this section
# Out:
# 0

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
import re
# Function to extract the digit from the size column
def extract_digit(size):
    match = re.search(r'\d+', size)
    if match:
        return match.group()
    else:
        return size  # Return original string if no digits found

# Apply the function to the size column to extract digits
df['size'] = df['size'].apply(extract_digit)

# Convert the extracted digits to integer type
df['size'] = df['size'].astype(int)
df.head()
# Out:
#         availability                  location  size total_sqft  bath   price
# 0  Future Possession  Electronic City Phase II     2       1056   2.0   39.07
# 1      Ready To Move                    others     4       2600   5.0  120.00
# 2      Ready To Move               Uttarahalli     3       1440   2.0   62.00
# 3      Ready To Move        Lingadheeranahalli     3       1521   3.0   95.00
# 4      Ready To Move                  Kothanur     2       1200   2.0   51.00

# %%
df.groupby('size')['size'].count()
# Out:
# size
# 1      656
# 2     5528
# 3     4856
# 4     1417
# 5      356
# 6      221
# 7      100
# 8       89
# 9       54
# 10      14
# 11       4
# 12       1
# 13       1
# 14       1
# 16       1
# 18       1
# 19       1
# 27       1
# 43       1
# Name: size, dtype: int64

# %%
# Filter out rows where size is less than 11
df = df[df['size'] < 11]
# Verify the changes by checking the unique sizes left
print(df['size'].unique())
# Out:
# [ 2  4  3  6  1  8  7  5  9 10]

# %%
df.head()
# Out:
#         availability                  location  size total_sqft  bath   price
# 0  Future Possession  Electronic City Phase II     2       1056   2.0   39.07
# 1      Ready To Move                    others     4       2600   5.0  120.00
# 2      Ready To Move               Uttarahalli     3       1440   2.0   62.00
# 3      Ready To Move        Lingadheeranahalli     3       1521   3.0   95.00
# 4      Ready To Move                  Kothanur     2       1200   2.0   51.00

# %% [markdown]
# ##Total sqft

# %%
df['total_sqft'].isna().sum()
#proceed in this section
# Out:
# 0

# %%
def clean_total_sqft(df):
    # Convert range to mean
    def range_to_mean(value):
        if '-' in value:
            low, high = value.split('-')
            return (float(low) + float(high)) / 2
        try:
            return float(value)
        except ValueError:
            return None
    df['total_sqft'] = df['total_sqft'].apply(range_to_mean)
    # Handling entries that could not be converted to float
    df['total_sqft'].fillna(df['total_sqft'].mean(), inplace=True)
    return df

df = clean_total_sqft(df)
df.head()
# Out:
#         availability                  location  size  total_sqft  bath   price
# 0  Future Possession  Electronic City Phase II     2      1056.0   2.0   39.07
# 1      Ready To Move                    others     4      2600.0   5.0  120.00
# 2      Ready To Move               Uttarahalli     3      1440.0   2.0   62.00
# 3      Ready To Move        Lingadheeranahalli     3      1521.0   3.0   95.00
# 4      Ready To Move                  Kothanur     2      1200.0   2.0   51.00

# %% [markdown]
# ##Bath

# %%
df['bath'].isna().sum()
#since the number of null values is not significant compared to total length of df, proceed in this section
# Out:
# 57

# %%
df['bath'].unique()
# Out:
# array([ 2.,  5.,  3.,  4.,  6.,  1.,  9., nan,  8.,  7., 11., 10., 14.,
#        12., 13.])

# %%
df.groupby('bath')['bath'].count()
# Out:
# bath
# 1.0      788
# 2.0     6908
# 3.0     3285
# 4.0     1226
# 5.0      524
# 6.0      271
# 7.0      102
# 8.0       64
# 9.0       42
# 10.0      13
# 11.0       2
# 12.0       6
# 13.0       2
# 14.0       1
# Name: bath, dtype: int64

# %%
len(df)
# Out:
# 13291

# %%
df = df[df['bath']<=10] #it is also dropping rows for which bath = null

# %%
len(df)
# Out:
# 13223

# %%
df.isna().sum()
# Out:
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# price           0
# dtype: int64

# %%
df.head()
# Out:
#         availability                  location  size  total_sqft  bath   price
# 0  Future Possession  Electronic City Phase II     2      1056.0   2.0   39.07
# 1      Ready To Move                    others     4      2600.0   5.0  120.00
# 2      Ready To Move               Uttarahalli     3      1440.0   2.0   62.00
# 3      Ready To Move        Lingadheeranahalli     3      1521.0   3.0   95.00
# 4      Ready To Move                  Kothanur     2      1200.0   2.0   51.00

# %%
df.isnull().sum()
# Out:
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# price           0
# dtype: int64

# %%
df.shape
# Out:
# (13223, 6)

# %% [markdown]
# #4. Feature engineering
# - Invent new features

# %%
df.head()
# Out:
#         availability                  location  size  total_sqft  bath   price
# 0  Future Possession  Electronic City Phase II     2      1056.0   2.0   39.07
# 1      Ready To Move                    others     4      2600.0   5.0  120.00
# 2      Ready To Move               Uttarahalli     3      1440.0   2.0   62.00
# 3      Ready To Move        Lingadheeranahalli     3      1521.0   3.0   95.00
# 4      Ready To Move                  Kothanur     2      1200.0   2.0   51.00

# %%
df['price_per_sqft'] = df['price']*100000/df['total_sqft']

# %% [markdown]
# #5. Clean Data:
# - Outlier Removal

# %%
# prompt: remove size outliers

# Remove outliers for size
lower_limit = df['size'].quantile(0.05)
upper_limit = df['size'].quantile(0.95)
df1 = df[(df['size'] >= lower_limit) & (df['size'] <= upper_limit)]
# Check the size distribution after outlier removal
df1['size'].describe()
# Out:
# count    12107.000000
# mean         2.717023
# std          0.779959
# min          2.000000
# 25%          2.000000
# 50%          3.000000
# 75%          3.000000
# max          5.000000
# Name: size, dtype: float64

# %%
# prompt: remove bath outliers

lower_limit = df1['bath'].quantile(0.05)
upper_limit = df1['bath'].quantile(0.95)
df2 = df1[(df1['bath'] >= lower_limit) & (df1['bath'] <= upper_limit)]
# Check the bath distribution after outlier removal
df2['bath'].describe()
# Out:
# count    11790.000000
# mean         2.598049
# std          0.825836
# min          2.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max          5.000000
# Name: bath, dtype: float64

# %%
# prompt: remove price_per_sqft outliers

lower_limit = df2['price_per_sqft'].quantile(0.05)
upper_limit = df2['price_per_sqft'].quantile(0.95)
df3 = df2[(df2['price_per_sqft'] >= lower_limit) & (df2['price_per_sqft'] <= upper_limit)]

# %%
df3.head()
# Out:
#         availability                  location  size  total_sqft  bath  \
# 0  Future Possession  Electronic City Phase II     2      1056.0   2.0
# 1      Ready To Move                    others     4      2600.0   5.0
# 2      Ready To Move               Uttarahalli     3      1440.0   2.0
# 3      Ready To Move        Lingadheeranahalli     3      1521.0   3.0
# 4      Ready To Move                  Kothanur     2      1200.0   2.0
#
#     price  price_per_sqft
# 0   39.07     3699.810606
# 1  120.00     4615.384615
# 2   62.00     4305.555556
# 3   95.00     6245.890861
# 4   51.00     4250.000000

# %%
len(df3)
# Out:
# 10613

# %%
df.price_per_sqft.describe()
# Out:
# count    1.322300e+04
# mean     7.914890e+03
# std      1.066339e+05
# min      2.678298e+02
# 25%      4.266200e+03
# 50%      5.437803e+03
# 75%      7.317073e+03
# max      1.200000e+07
# Name: price_per_sqft, dtype: float64

# %%
df = df3.drop("price_per_sqft", axis=1)

# %% [markdown]
# #6. Split the data into x and y label

# %%
x = df.drop(["price"],axis=1)
y = df["price"]

# %% [markdown]
# #7. Split the data into x_train, x_test, y_train, y_test

# %%
# prompt: Split the data into x_train, x_test, y_train, y_test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8490 entries, 8277 to 293
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   availability  8490 non-null   object
#  1   location      8490 non-null   object
#  2   size          8490 non-null   int64
#  3   total_sqft    8490 non-null   float64
#  4   bath          8490 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 398.0+ KB

# %% [markdown]
# #8. Handling missing values
# - Dropping rows and columns based on null values
# - Filling missing data with pandas
# - Filling missing values with sklearn
# - Add _is_missing column

# %%
x_train.isna().sum()
# Out:
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# dtype: int64

# %%
x_test.isna().sum()
# Out:
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# dtype: int64

# %%
#no missing values, since null values have been dropped in the Handling Features step: they are dropped because of their numbers,
#since their number was negligent compared to total length of the dataframe
#if the number of missing values is significant, then that particular feature will taken care in the handling missing values section

# %% [markdown]
# #9. Sort or Add columns
# - x_train.shape == x_valid.shape

# %%
x_train.shape
# Out:
# (8490, 5)

# %%
x_test.shape #same no of columns
# Out:
# (2123, 5)

# %% [markdown]
# #10. Feature scaling

# %%
x_train.head()
# Out:
#             availability          location  size  total_sqft  bath
# 8277       Ready To Move            others     2      1000.0   2.0
# 7565   Future Possession  Ramamurthy Nagar     2      1200.0   2.0
# 3689       Ready To Move            Hebbal     4      2700.0   2.0
# 11046      Ready To Move            others     3      1645.0   3.0
# 8495       Ready To Move         Bellandur     2      1150.0   2.0

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8490 entries, 8277 to 293
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   availability  8490 non-null   object
#  1   location      8490 non-null   object
#  2   size          8490 non-null   int64
#  3   total_sqft    8490 non-null   float64
#  4   bath          8490 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 398.0+ KB

# %%
# prompt: function for feature scaling the total_sqft column
from sklearn.preprocessing import StandardScaler
def scale_total_sqft(df):
    # Feature scaling (Standardization)
    # scaler = StandardScaler()
    # df['total_sqft'] = scaler.fit_transform(df[['total_sqft']])
    return df

# %%
x_train_scaled = scale_total_sqft(x_train)
x_test_scaled = scale_total_sqft(x_test)

# %%
x_train_scaled.head()
# Out:
#             availability          location  size  total_sqft  bath
# 8277       Ready To Move            others     2      1000.0   2.0
# 7565   Future Possession  Ramamurthy Nagar     2      1200.0   2.0
# 3689       Ready To Move            Hebbal     4      2700.0   2.0
# 11046      Ready To Move            others     3      1645.0   3.0
# 8495       Ready To Move         Bellandur     2      1150.0   2.0

# %%
x_train_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8490 entries, 8277 to 293
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   availability  8490 non-null   object
#  1   location      8490 non-null   object
#  2   size          8490 non-null   int64
#  3   total_sqft    8490 non-null   float64
#  4   bath          8490 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 398.0+ KB

# %% [markdown]
# #11. Convert Categorical Features into Numericals
# - One hot encoder: Lasso or Ridge
# - Label encoding: XGBoost and RandomForest
# - Lower cardinality columns: One hot encoding
# - High cardinality columns: Target encoding, Ordinal encoding
# - Convert to category
# - https://www.kaggle.com/code/gokuleshwaran/feature-engineering-for-house-prices/edit

# %%
x_train_scaled.head()
# Out:
#             availability          location  size  total_sqft  bath
# 8277       Ready To Move            others     2      1000.0   2.0
# 7565   Future Possession  Ramamurthy Nagar     2      1200.0   2.0
# 3689       Ready To Move            Hebbal     4      2700.0   2.0
# 11046      Ready To Move            others     3      1645.0   3.0
# 8495       Ready To Move         Bellandur     2      1150.0   2.0

# %%
# x_train_scaled['area_type'].unique()

# %%
x_train_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8490 entries, 8277 to 293
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   availability  8490 non-null   object
#  1   location      8490 non-null   object
#  2   size          8490 non-null   int64
#  3   total_sqft    8490 non-null   float64
#  4   bath          8490 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 398.0+ KB

# %%
# One-hot encode the categorical columns
x_train_encoded = pd.get_dummies(x_train_scaled, columns=[ 'availability', 'location'])
x_test_encoded = pd.get_dummies(x_test_scaled, columns=['availability', 'location'])
# Display the first few rows of the DataFrame to confirm changes
print(x_train_encoded.columns)
# Out:
# Index(['size', 'total_sqft', 'bath', 'availability_Future Possession',
#        'availability_Ready To Move', 'location_1st Phase JP Nagar',
#        'location_2nd Stage Nagarbhavi', 'location_5th Phase JP Nagar',
#        'location_6th Phase JP Nagar', 'location_7th Phase JP Nagar',
#        ...
#        'location_Varthur', 'location_Vidyaranyapura', 'location_Vijayanagar',
#        'location_Vittasandra', 'location_Whitefield',
#        'location_Yelachenahalli', 'location_Yelahanka',
#        'location_Yelahanka New Town', 'location_Yeshwanthpur',
#        'location_others'],
#       dtype='object', length=154)

# %%
x_train_encoded.shape, x_test_encoded.shape
# Out:
# ((8490, 154), (2123, 152))

# %%
y_train.shape, y_test.shape
# Out:
# ((8490,), (2123,))

# %% [markdown]
# #12. Sort or Add columns
# - x_train.shape == x_valid.shape

# %%
# prompt: colomns missing in x_train vs x_test

missing_cols = set(x_train_encoded.columns) - set(x_test_encoded.columns)
print(missing_cols)
for col in missing_cols:
  x_test_encoded[col]=0
# Out:
# {'location_Anekal', 'location_2nd Stage Nagarbhavi'}

# %%
x_train_encoded.shape, x_test_encoded.shape
# Out:
# ((8490, 154), (2123, 154))

# %%
# prompt: sort the columns in x_train_encoded and x_test_encoded

sorted_columns = sorted(x_train_encoded.columns)

x_train_encoded = x_train_encoded[sorted_columns]
x_test_encoded = x_test_encoded[sorted_columns]

print(x_train_encoded.columns)
# Out:
# Index(['availability_Future Possession', 'availability_Ready To Move', 'bath',
#        'location_1st Phase JP Nagar', 'location_2nd Stage Nagarbhavi',
#        'location_5th Phase JP Nagar', 'location_6th Phase JP Nagar',
#        'location_7th Phase JP Nagar', 'location_8th Phase JP Nagar',
#        'location_9th Phase JP Nagar',
#        ...
#        'location_Vijayanagar', 'location_Vittasandra', 'location_Whitefield',
#        'location_Yelachenahalli', 'location_Yelahanka',
#        'location_Yelahanka New Town', 'location_Yeshwanthpur',
#        'location_others', 'size', 'total_sqft'],
#       dtype='object', length=154)

# %% [markdown]
# #13. Fit the train data into models
# - compare the aaccuracy or other metrics.

# %%
# prompt: import XGBoostRegressor and fit the model

from xgboost import XGBRegressor
# Instantiate the XGBRegressor model
xgb_model = XGBRegressor()
# Fit the model to the training data
xgb_model.fit(x_train_encoded, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xgb_model.score(x_test_encoded,y_test)
# Out:
# 0.7726784110137359

# %%
# prompt: import DecisionTreeregressor and fit the model

from sklearn.tree import DecisionTreeRegressor
# Instantiate the DecisionTreeRegressor model
dt_model = DecisionTreeRegressor()
# Fit the model to the training data
dt_model.fit(x_train_encoded, y_train)
dt_model.score(x_test_encoded,y_test)
# Out:
# 0.6507969385326933

# %%
# prompt: import linearRegressor and fit the model

from sklearn.linear_model import LinearRegression

# Instantiate the LinearRegression model
linear_model = LinearRegression()

# Fit the model to the training data
linear_model.fit(x_train_encoded, y_train)

# Print the model's score on the test data
print(linear_model.score(x_test_encoded, y_test))
# Out:
# 0.7639326734335096

# %%
# prompt: import RandomForestRegressor and fit the model

from sklearn.ensemble import RandomForestRegressor

# Instantiate the RandomForestRegressor model
rf_model = RandomForestRegressor()

# Fit the model to the training data
rf_model.fit(x_train_encoded, y_train)

# Print the model's score on the test data
print(rf_model.score(x_test_encoded, y_test))
# Out:
# 0.7776140898803345

# %% [markdown]
# #14. Evaluation
# - show_scores(model, x_train, x_test, y_train, y_test)
# - score_dataset()
# - y_preds = model.predict()
# - y_probs = model.predict_proba()

# %%
# prompt: function which take model as a parameter and computes MAE, MSE, RMSLE, R2 score on x_train and x_test
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score
import numpy as np
def show_scores(model, x_train, x_test, y_train, y_test):
  # Calculate the model's predictions
  train_preds = model.predict(x_train)
  test_preds = model.predict(x_test)

  # Evaluate the model's performance using various metrics
  mae_train = mean_absolute_error(y_train, train_preds)
  mae_test = mean_absolute_error(y_test, test_preds)
  mse_train = mean_squared_error(y_train, train_preds)
  mse_test = mean_squared_error(y_test, test_preds)
  r2_train = r2_score(y_train, train_preds)
  r2_test = r2_score(y_test, test_preds)

  # Print the results
  print("Model:", model.__class__.__name__)
  print("-" * 30)
  print("Training set:")
  print("- RMSE:", np.sqrt(mse_train))
  print("- MAE:", mae_train)
  print("- R2 Score:", r2_train)
  print("-" * 30)
  print("Test set:")
  print("- RMSE:", np.sqrt(mse_test))
  print("- MAE:", mae_test)
  print("- R2 Score:", r2_test)

# %% [markdown]
# #15. Tune hyperparameters
# - RandomizedSearchCV
# - GridSearchCV
# - (on subset to reduce training time by adjusting max_samples parameter)

# %%
x_test_encoded.shape, x_train_encoded.shape
# Out:
# ((2123, 154), (8490, 154))

# %%
# prompt: Implement RandomizedSearchCV on RandomForestRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV

# Define the hyperparameter space
hyperparameter_space = {"n_estimators": np.arange(10, 100, 10),
           "max_depth": [None, 3, 5, 10],
           "min_samples_split": np.arange(2, 20, 2),
           "min_samples_leaf": np.arange(1, 20, 2)
                        }

# Instantiate the Random Forest Regressor
rf_model = RandomForestRegressor(random_state=42)

# Define the RandomizedSearchCV object
random_search = RandomizedSearchCV(
    estimator=rf_model,
    param_distributions=hyperparameter_space,
    n_iter=100,
    scoring='neg_mean_squared_error',
    cv=5,
    n_jobs=-1,
    random_state=42,
    verbose = True
)

# Fit the RandomizedSearchCV object to the training data
random_search.fit(x_train_encoded, y_train)

# Print the best hyperparameters
print(random_search.best_params_)

# Get the best model
best_model = random_search.best_estimator_

# Evaluate the best model
show_scores(best_model, x_train_encoded, x_test_encoded, y_train, y_test)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# {'n_estimators': 80, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_depth': None}
# Model: RandomForestRegressor
# ------------------------------
# Training set:
# - RMSE: 26.36632521341511
# - MAE: 13.970592845249314
# - R2 Score: 0.8911473311543616
# ------------------------------
# Test set:
# - RMSE: 33.88779785612469
# - MAE: 19.297343725094944
# - R2 Score: 0.7873704808293586

# %%
show_scores(best_model, x_train_encoded, x_test_encoded, y_train, y_test)
# Out:
# Model: RandomForestRegressor
# ------------------------------
# Training set:
# - RMSE: 26.36632521341511
# - MAE: 13.970592845249314
# - R2 Score: 0.8911473311543616
# ------------------------------
# Test set:
# - RMSE: 33.88779785612469
# - MAE: 19.297343725094944
# - R2 Score: 0.7873704808293586

# %%
# Instantiate the Random Forest Regressor with the best hyperparameters
rf_model = RandomForestRegressor(n_estimators=80, min_samples_split=16, min_samples_leaf=1, max_depth=None, random_state=42)

# Fit the model to the training data
rf_model.fit(x_train_encoded, y_train)

# Evaluate the model
show_scores(rf_model, x_train_encoded, x_test_encoded, y_train, y_test)
# Out:
# Model: RandomForestRegressor
# ------------------------------
# Training set:
# - RMSE: 26.36632521341511
# - MAE: 13.970592845249314
# - R2 Score: 0.8911473311543616
# ------------------------------
# Test set:
# - RMSE: 33.88779785612469
# - MAE: 19.297343725094944
# - R2 Score: 0.7873704808293586

# %%
# prompt: Implement RandomizedSearchCV on DecisionTreeRegressor

import numpy as np
from sklearn.tree import DecisionTreeRegressor

# Define the hyperparameter space
hyperparameter_space = {"max_depth": [None, 3, 5, 10],
           "min_samples_split": np.arange(2, 20, 2),
           "min_samples_leaf": np.arange(1, 20, 2)
                        }

# Instantiate the Decision Tree Regressor
dt_model = DecisionTreeRegressor(random_state=42)

# Define the RandomizedSearchCV object
random_search = RandomizedSearchCV(
    estimator=dt_model,
    param_distributions=hyperparameter_space,
    n_iter=100,
    scoring='neg_mean_squared_error',
    cv=5,
    n_jobs=-1,
    random_state=42,
    verbose = True
)

# Fit the RandomizedSearchCV object to the training data
random_search.fit(x_train_encoded, y_train)

# Print the best hyperparameters
print(random_search.best_params_)

# Get the best model
best_model = random_search.best_estimator_

# Evaluate the best model
show_scores(best_model, x_train_encoded, x_test_encoded, y_train, y_test)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# {'min_samples_split': 6, 'min_samples_leaf': 1, 'max_depth': 10}
# Model: DecisionTreeRegressor
# ------------------------------
# Training set:
# - RMSE: 29.820640833839228
# - MAE: 18.91610078627339
# - R2 Score: 0.8607568573625477
# ------------------------------
# Test set:
# - RMSE: 37.73872046761237
# - MAE: 21.783710424147213
# - R2 Score: 0.7362993477107584

# %%
# prompt: Implement RandomizedSearchCV on KNN

import numpy as np
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsRegressor

# Define the hyperparameter space
hyperparameter_space = {
    "n_neighbors": np.arange(1, 21),
    "weights": ["uniform", "distance"],
    "algorithm": ["auto", "ball_tree", "kd_tree", "brute"],
    "leaf_size": np.arange(1, 50, 5),
}

# Instantiate the KNNRegressor model
knn_model = KNeighborsRegressor()

# Define the RandomizedSearchCV object
random_search = RandomizedSearchCV(
    estimator=knn_model,
    param_distributions=hyperparameter_space,
    n_iter=100,
    scoring="neg_mean_squared_error",
    cv=5,
    n_jobs=-1,
    random_state=42,
    verbose=True,
)

# Fit the RandomizedSearchCV object to the training data
random_search.fit(x_train_encoded, y_train)

# Print the best hyperparameters
print(random_search.best_params_)

# Get the best model
best_model = random_search.best_estimator_

# Evaluate the best model
show_scores(best_model, x_train_encoded, x_test_encoded, y_train, y_test)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# {'weights': 'distance', 'n_neighbors': 14, 'leaf_size': 36, 'algorithm': 'ball_tree'}
# Model: KNeighborsRegressor
# ------------------------------
# Training set:
# - RMSE: 12.818398410634835
# - MAE: 4.56303936136498
# - R2 Score: 0.9742719184236397
# ------------------------------
# Test set:
# - RMSE: 37.69251527904415
# - MAE: 20.781289207966758
# - R2 Score: 0.7369446732173408

# %%
knn_model = KNeighborsRegressor()
knn_model.fit(x_train_encoded, y_train)
show_scores(knn_model, x_train_encoded, x_test_encoded, y_train, y_test)
# Out:
# Model: KNeighborsRegressor
# ------------------------------
# Training set:
# - RMSE: 32.91833206801233
# - MAE: 18.293956654888106
# - R2 Score: 0.8303259148355041
# ------------------------------
# Test set:
# - RMSE: 37.06201100923946
# - MAE: 22.042230805463966
# - R2 Score: 0.7456716211966088

# %%
# prompt: randomforest regressor with {'n_estimators': 80, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_depth': None}

rf_model = RandomForestRegressor(n_estimators=80, min_samples_split=16, min_samples_leaf=1, max_depth=None, random_state=42)
rf_model.fit(x_train_encoded, y_train)
# Out:
# RandomForestRegressor(min_samples_split=16, n_estimators=80, random_state=42)

# %%
  train_preds = rf_model.predict(x_train_encoded)
  # Evaluate the model's performance using various metrics
  mae_train = mean_absolute_error(y_train, train_preds)
  mse_train = mean_squared_error(y_train, train_preds)
  r2_train = r2_score(y_train, train_preds)

  # Print the results
  print("-" * 30)
  print("Training set:")
  print("- RMSE:", np.sqrt(mse_train))
  print("- MAE:", mae_train)
  print("- R2 Score:", r2_train)
# Out:
# ------------------------------
# Training set:
# - RMSE: 26.36632521341511
# - MAE: 13.970592845249314
# - R2 Score: 0.8911473311543616

# %%
  test_preds = rf_model.predict(x_test_encoded)
  # Evaluate the model's performance using various metrics
  mae_test = mean_absolute_error(y_test, test_preds)
  mse_test = mean_squared_error(y_test, test_preds)
  r2_test = r2_score(y_test, test_preds)

  # Print the results
  print("-" * 30)
  print("Training set:")
  print("- RMSE:", np.sqrt(mse_test))
  print("- MAE:", mae_test)
  print("- R2 Score:", r2_test)
# Out:
# ------------------------------
# Training set:
# - RMSE: 33.88779785612469
# - MAE: 19.297343725094944
# - R2 Score: 0.7873704808293586

# %%
# prompt: save rf_model

# !pip install joblib
import joblib

# Save the model as a pickle file
joblib.dump(rf_model, 'rf_model.pkl')
# Out:
# ...
# ['rf_model.pkl']

# %%
# prompt: save rf_model in sav

# !pip install pickle5
import pickle5 as pickle
with open('rf_model.sav', 'wb') as f:
    pickle.dump(rf_model, f)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255320 sha256=8edb98395a40837a6b9dc4575a427551429dfec196f25b06750e8bda30776687
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# ...

# %%
x_test.head()
# Out:
#            availability         location  size  total_sqft  bath
# 9672      Ready To Move       Whitefield     2      1100.0   2.0
# 3023      Ready To Move    Akshaya Nagar     4      1080.0   4.0
# 8208      Ready To Move  Old Madras Road     4      3900.0   4.0
# 1293  Future Possession        Hosa Road     3      1726.0   3.0
# 7129      Ready To Move        Yelahanka     2      1315.0   2.0
